# %% [markdown]
# <a href="https://colab.research.google.com/github/baijucode/python_training/blob/master/tupleandset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cant change anything in tuple
int_tuple=(1,2,3)
print(int_tuple)
# Out:
# (1, 2, 3)

# %%
print (type(int_tuple))
# Out:
# <class 'tuple'>

# %%
mixed_tuple=("ktm",1,52)
print(mixed_tuple)
# Out:
# ('ktm', 1, 52)

# %%
num_1=(1,)
print(type(num_1))
# Out:
# <class 'tuple'>

# %%
print(mixed_tuple[0:3:2])
# Out:
# ('ktm', 52)

# %%
stu_tuple=("stu_1","stu_2","stu_3")
name_1,name_2,name_3=stu_tuple
print(name_2)
# Out:
# stu_2

# %%
name_1,*other_students=stu_tuple
print(name_1)
print(other_students)
# Out:
# stu_1
# ['stu_2', 'stu_3']

# %%
#zip
country_list=['Bangladesh','Nepal']
city_list=['ktm','Dhaka','Bkt']
population_list=[155555,200000,800000]
combined_data=list(zip(country_list,city_list,population_list))
print(combined_data)
# Out:
# [('Bangladesh', 'ktm', 155555), ('Nepal', 'Dhaka', 200000)]

# %%
mixed_tuple=(123,True,"Apple",["cat","Dog"],('dell','hp'),"Apple")
print(len(mixed_tuple))
print(mixed_tuple.count("Apple"))
# Out:
# 6
# 2

# %%
num_list=(1,2,3,4)
print()

# %%
#set
num_set={1,2,"apple",3,1}
print(num_set)
print(type(num_set))
# Out:
# {1, 2, 3, 'apple'}
# <class 'set'>

# %%
#cannot store mutable data
mixed_set={1,2,"apple",3,1,("python","ml")}
print(mixed_set)
# Out:
# {1, 2, 3, 'apple', ('python', 'ml')}

# %%
#data related operations
mixed_set.add("orange")
print(mixed_set)
# Out:
# {1, 2, 3, 'apple', ('python', 'ml'), 'orange'}

# %%
mixed_set.add("orange")
print(mixed_set)
# Out:
# {1, 2, 3, 'apple', ('python', 'ml'), 'orange'}

# %%
set_1={1,4}
set_2={"cat","dog"}
set_3="apple"
set_1.update(set_3)#elevent to extent
print(set_1)
# Out:
# {1, 'p', 4, 'e', 'a', 'l'}

# %%
#remove item
set_1.remove("4")
print(set_1)
set_2.pop(1)
print(set_1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_746/847437776.py in <cell line: 0>()
#       1 #remove item
# ----> 2 set_1.remove("4")
#       3 print(set_1)
#       4 set_2.pop(1)
#       5 print(set_1)
#
# KeyError: '4'

# %%
set_1={1,7}
set_2={1,5}
set_3={1,5,7}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_746/1394566787.py in <cell line: 0>()
#       3 set_3={1,5,7}
#       4
# ----> 5 is_disjoint=set_1.isjoint(set_2)
#       6 print(is_disjoint)
#
# AttributeError: 'set' object has no attribute 'isjoint'

# %%
set_3.discard("2")
print(set_3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_746/64952560.py in <cell line: 0>()
# ----> 1 set_3.discard("2")
#       2 print(set_3)
#
# AttributeError: 'str' object has no attribute 'discard'

# %%
python_student={"ram","sita","Rita"}
data_science={"hari","sita","gita","ram"}
django_student={"ram","gita","nira"}

common_student=python_student.intersection(data_science)
print(common_student)

union=python_student.union(data_science)
print(union)

symmetric_difference=python_student.symmetric_difference(data_science)#^
print(symmetric_difference)

Difference=python_student-data_science #difference
print(Difference)

Or=python_student|data_science#or
print(Or)
# Out:
# {'sita', 'ram'}
# {'gita', 'Rita', 'sita', 'hari', 'ram'}
# {'gita', 'Rita', 'hari'}
# {'Rita'}
# {'gita', 'Rita', 'sita', 'hari', 'ram'}

# %%
a=["ram","shyam"]
b=set(a)
print(b)
# Out:
# {'shyam', 'ram'}

# %%
is_subset=set_2.issubset(set_1)
print(is_subset)
# Out:
# False

# %%
set_1=frozenset({1,7})
set_2=frozenset({1,5})
print(set_1)
# Out:
# frozenset({1, 7})
