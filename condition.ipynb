# %% [markdown]
# <a href="https://colab.research.google.com/github/baijucode/python_training/blob/master/condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=-7
if n%2==0 and n>0:
    print (n,"is positive even number")
elif n<0 and n%2!=0:
  print(n,"is a negative odd number")
elif n<0:
    print (n,"is a negative number")
elif n>0:
  print(n,"is a positive number")
elif n==0:
  print(n,"is zero")
# Out:
# -7 is a negative odd number

# %%
num=79
if num>0:
  if num%2==0:
    print("positive even number")
  else:
    print("positive odd number")
elif num<0:
  print("Negative number")
else:
  print("zero")
# Out:
# positive odd number
